# %%
#Coffee Machine
print('**********WELCOME TO COFFEE DAY**********')
print(' ')
class shop():
    def __init__(self,water,milk,coffee):# __init__ -it is a default constructor
        self.water=water
        self.milk=milk
        self.coffee=coffee
    #def show(self):
     #   print(self.water,self.milk,self.coffee)
    def espresso(self):
        if choice==1:
            if self.water>100 and self.milk>150 and self.coffee>20:
                print('*************Your Order Is Being Processed*************')
                pay=int(input('Please pay $4 Dollars For You Espresso:'))
                if pay==4:
                    print('PAYMENT SUCCESSFULL')
                    print('*' *30)
                    print('Here Is Your Espresso.Enjoy!')
                    print('*' *30)
                elif pay>4:
                    change=pay-4
                    print('Here is Your change:',pay-4,'$')
                    print(' ')
                    print('*' *30)
                    print('Here Is Your Espresso.Enjoy!')
                    print('*' *30)
                else:
                    print('Please enter the correct Amount')
            else:
                print('**************Sorry We Dont Have Enough Stuffs To Prepare ESpresso *************** \n PLEASE SELECT SOME OTHER DRINK ')
                print(' ')
                print(' ')
                
class shop_1(shop):
    def latte(self):
        if int(choice==2):
            if self.water>200 and self.milk>150 and self.coffee>100:
                print('*************Your Order Is Being Processed**************')
                amount=int(input('Please Pay $5 Dollars for Your Latte:'))
                if amount==5:
                    print('Payment Successfull \n    Here Is Your Latte.Enjoy!')
                elif amount>5:
                    balance=amount-5
                    print('Here is your change:',balance,'$')
                    print(' ')
                    print('*' *30)
                    print('Here Is Your Latte.Enjoy!')
                    print('*' *30)
                else:
                    print('Please Enter The Proper Amount:')
            else:
                print('************Sorry We Dont Have Enough Stuffs To Prepare Lattee***************** \n PLEASE SELECT SOME OTHER DRINK ')
                print(' ')
                print(' ')
                
class shop_2(shop):
    def cappuccino(self):
        if choice==3:
            if self.water>100 and self.milk>150 and self.coffee>50:
                print('**************Your Order Is Being Processed*****************')
                pay=int(input('Please Pay $7 Dollars :'))
                if pay==7:
                    print('PAYMENT SUCCESFULL')
                    print('*' *30)
                    print('Here is your Cappuccino')
                    print('*' *30)
                elif pay>7:
                    balance=pay-7
                    print('Here is Your Change:',balance,'$')
                    print('*' *30)
                    print('Here is your Cappuccino.ENJOY!')
                    print('*' *30)
                else:
                    print('Please enter the correct Amount')
            else:
                print('****************Sorry We Dont Have Enough Stuffs To Prepare Cappuccino ****************\n PLEASE SELECT SOME OTHER DRINK ')
                print(' ')
                print(' ')

        
'''class espresso(shop):
    #super().__init__(water,milk,coffee)
    def order(self):
        if self.water>100 and self.milk>100 and self.coffee>100:
            print('Your Order Is Being Prepared')
        else:
            print('Sorry We Dont have available stuffs to make espresso ')
#available=shop(220,100,500)
#available.show()
#obj_es=espresso(200,100,500)
#obj_es.order()
'''

while True:
    
    print('What would you like to order \n 1.Espresso \n 2.Latte \n 3.Cappuccino \n 4.Exit ')
    choice=int(input('Please Enter Your Choice:'))
    print(' ')
    obj_shop=shop(200,500,500)
    obj_shop.espresso() 
    obj_shop_1=shop_1(500,200,600)
    obj_shop_1.latte()
    object_1=shop_2(500,200,400)
    object_1.cappuccino()
    
    
    if choice==4:
        print('Exit Succesfully')
        break
# Out:
# **********WELCOME TO COFFEE DAY**********
#
# What would you like to order
#  1.Espresso
#  2.Latte
#  3.Cappuccino
#  4.Exit
# Please Enter Your Choice:1
#
# *************Your Order Is Being Processed*************
# Please pay $4 Dollars For You Espresso:2
# Please enter the correct Amount
# What would you like to order
#  1.Espresso
#  2.Latte
#  3.Cappuccino
#  4.Exit
# Please Enter Your Choice:3
#
# **************Your Order Is Being Processed*****************
# Please Pay $7 Dollars :4
# Please enter the correct Amount
# What would you like to order
#  1.Espresso
#  2.Latte
#  3.Cappuccino
#  4.Exit
# Please Enter Your Choice:4
#
# Exit Succesfully
